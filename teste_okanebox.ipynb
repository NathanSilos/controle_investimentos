# %%
import requests
import datetime as dt

# %%
acao = 'ENBR3'
hoje = dt.date.today().strftime('%Y%m%d')
hoje
# Out:
# '20220830'

# %%
url = f'https://www.okanebox.com.br/api/acoes/hist/{acao}/{hoje}/{hoje}/'

# %%
url = 'https://www.okanebox.com.br/api/acoes/hist/PETR4/20190709/20200709/'

# %%
# “DATPRG”: Data do Fechamento
# “PREABE”:  Preço de Abertura
# “PREMAX”:  Preço Máximo
# “PREMIN”:  Preço Mínimo
# “PREMED”: Preço Médio
# “PREULT”:  Preço de Fechamento
# “QUATOT”:  Quantidade de Negocios
# “VOLTOT”:  Volume de Negocios

# %%
api = requests.get(url)

# %%
api.headers
# Out:
# {'Server': 'nginx/1.17.10 (Ubuntu)', 'Date': 'Tue, 30 Aug 2022 23:11:22 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*', 'Content-Encoding': 'gzip'}

# %%
api.text
# Out:
# '[{"DATPRG": "2019-07-10T00:00:00", "PREABE": 28.0, "PREMAX": 28.27, "PREMIN": 27.97, "PREMED": 28.16, "PREULT": 28.07, "QUATOT": 50715800, "VOLTOT": 1428422095.0}, {"DATPRG": "2019-07-11T00:00:00", "PREABE": 28.2, "PREMAX": 28.51, "PREMIN": 28.16, "PREMED": 28.33, "PREULT": 28.4, "QUATOT": 48206900, "VOLTOT": 1365836351.0}, {"DATPRG": "2019-07-12T00:00:00", "PREABE": 28.54, "PREMAX": 28.74, "PREMIN": 28.41, "PREMED": 28.57, "PREULT": 28.53, "QUATOT": 40908900, "VOLTOT": 1168800981.0}, {"DATPRG": "2019-07-15T00:00:00", "PREABE": 28.59, "PREMAX": 28.65, "PREMIN": 28.18, "PREMED": 28.38, "PREULT": 28.18, "QUATOT": 36592400, "VOLTOT": 1038696214.0}, {"DATPRG": "2019-07-16T00:00:00", "PREABE": 28.28, "PREMAX": 28.33, "PREMIN": 27.6, "PREMED": 27.94, "PREULT": 27.83, "QUATOT": 54789300, "VOLTOT": 1530995635.0}, {"DATPRG": "2019-07-17T00:00:00", "PREABE": 27.99, "PREMAX": 28.0, "PREMIN": 27.64, "PREMED": 27.75, "PREULT": 27.68, "QUATOT": 28923500, "VOLTOT": 802850096.0}, {"DATPRG": "2019-0
# ...
